# %%
from YakGrabber import *

import numpy as np

# %%
# Module that handles Yak retrieval, without any preprocessing.
# yg.fetch_yaks gets us all the yaks that would appear to a user.
# (usually on the order of the 100 most recent yaks)
# The location is set to Stanford's lat/long coords, because 
# that's the location we're interested in.
yg = YakGrabber()

# We were thinking about having some sort of time limit for yaks to accumulate
# upvotes, but that didn't seem objective, since this depends on the activity
# of yik yak at the time of the yak: for instance a yak posted at 2am might take
# more time to be upvoted properly than a yak posted at 6pm. 
# Waiting until yaks are no longer in the "new" section solves this because 
# the "new" section's size is fixed, and yaks don't leave after some specific time 
# period.

# Set of all yaks that are 'old' and aren't being voted on actively any more
# These are either yaks that have been voted off, or yaks that are no longer 
# found in the recents section. This is an array of tuples of the form 
# (messageID, handle, message, numberOfLikes)
# If the yak was voted off, the numberOfLikes is set to float("-inf")
completed_yaks = np.array([])

# Set of yaks that are still being actively voted on.
# This will be a dict, of type: messageID -> (handle, message, numberOfLikes)
current_yaks = {}

# %%
most_recent_yaks = yg.fetch_yaks()
def make_dict(yaks_arr):
    return {yak["messageID"]:((yak['handle'] if ('handle' in yak) and yak['handle'] else ""), 
                              yak['message'], 
                              yak['numberOfLikes']) for yak in yaks_arr}
new_yaks_dict = make_dict(most_recent_yaks)


# MOVE ALL OLD YAKS INTO completed_yaks
keys_to_remove = set()
for yak_id in current_yaks:
    if yak_id not in new_yaks_dict:
        # Then the yak is no longer in circulation. This could be for two 
        # reasons. Either the yak has been voted off, or it is too old.
        # it's not actually possible to know exactly which one it is, but 
        # we simply use the heuristic that if the yak's numberOfLikes 
        # when it is in current_yaks is negative, we assume that it was voted off
        if current_yaks[yak_id]['numberOfLikes'] < 0:
            completed_yaks.append((yak_id, 
                                   current_yaks[yak_id]['handle'], 
                                   current_yaks[yak_id]['message'], 
                                   float("-inf")))
        else:
            completed_yaks.append((yak_id, 
                                   current_yaks[yak_id]['handle'], 
                                   current_yaks[yak_id]['message'], 
                                   current_yaks[yak_id]['numberOfLikes']))
        keys_to_remove.add(yak_id)
for to_del in keys_to_remove:
    
# UPDATE ALL CURRENT YAKS THAT ARE LEFT
# Out:
# {u'R/55636ed92b4660cab9f65217a4292': (u'\U0001f525\U0001f525\U0001f525\U0001f525\U0001f525\U0001f525',
#   u'Using my mixtape to boil this water ',
#   93),
#  u'R/55636f44443b46f78df88e9b92b81': (u'whereMySophsAt',
#   u'Tryna declare before the end of the year amirite ',
#   5),
#  u'R/55636fbedfda37c9bc63e68218ba0': ('',
#   u'I wish I grew up in a household of really strong intellectuals who had a way with words and logic and being able to forge their realities.',
#   18),
#  u'R/556371d2b474d659ed6ca9f1b4c33': ('',
#   u'My small bladder is the main reason I get out of bed in the mornings.',
#   74),
#  u'R/556372d65cf9a98c029c724d5abaa': ('',
#   u'Girls, do you masturbate while on your period?',
#   16),
#  u'R/556373455c906d41729184d7234f4': ('',
#   u'Sorority girls are actually stereotypically boring',
#   28),
#  u'R/55637389a40d7cab3722172be7a05': ('',
#   u'Gender neutral pronouns, blah, blah, blah ',
#   5),
#  u'R/556373bca991846d8446d18086647': (u'thebestweekends',
#   u'When you wake up, think "...nope," and then roll back over and pretend it didn\'t happen',
#   47),
#  u'R/5563740af0bdd7d45b144cbf5bf52': (u'dorm',
#   u'You have a drinking problem ',
#   6),
#  u'R/556374d6db762d6f0a371188b4b3c': ('',
#   u'When your friends are whores to money, attention, their egos and you realize your presence is just a silenced crutch for their loneliness.',
#   12),
#  u'R/5563760a83b59c59da5506ee6dc33': ('',
#   u'Uh, roommate just walked in on me. I just casually chilled with a pillow on my crotch until he left. ',
#   37),
#  u'R/55637627937d8f53cd3672718094c': (u'concerned',
#   u'when the check engine light is on in your super shuttle........ ',
#   61),
#  u'R/5563769899dc96073079ca921ea0f': ('', u'Summer bulk 2015!', 8),
#  u'R/556379792c2fba82024d0e28a37ac': ('',
#   u'Arrived home to find that yakkers take pm for granted. They need to check their privilege ',
#   17),
#  u'R/55637c257f4242ec0f0179af18e1e': ('',
#   u'Happiness at this school is preceded by drive and the guilt that comes from not being able to provide for that drive all the time.',
#   14),
#  u'R/55637c46150304482e56ac6a6b55c': ('', u'Only money buys you time ', 0),
#  u'R/55637c4eac96c74004e22d7291af4': ('', u'Money is the power ', 2),
#  u'R/55637d3e3846af4578aefe2dd24fd': (u'Uncrushed',
#   u"Stanford Crushes is ending and I've still never been mentioned.",
#   53),
#  u'R/55637e958450b6c2f5aab21d0805e': ('', u'Is the library open today?', 3),
#  u'R/55637eae3832f1cd781b4b2ff0e8b': ('',
#   u"I get why people don't appreciate them, but I personally feel my humanities major is preparing me well for life outside of Stanford",
#   61),
#  u'R/55637f7dc893da0356bf71301d11b': ('',
#   u'Why do I get bored of being in a relationship?',
#   13),
#  u'R/55637fabd5cc2e67da9ae18cfc702': ('',
#   u"Won't have my own room next year, gonna miss walking around pantsless \U0001f61e",
#   38),
#  u'R/55637fe0e7d6943dc4f8dfc85cda8': (u'ThanksFettyWap',
#   u"I can't read the year 1738 normally anymore",
#   22),
#  u'R/556382601683013db13bac20e36c1': ('',
#   u'I have finally come out!! Feels so good! Thank you Jesus!',
#   49),
#  u'R/5563843216e70b4398fb674139dcd': ('',
#   u"I'm starting to realize that I don't like my roommate, but I already agreed to live together next year. Any advice?",
#   16),
#  u'R/556386f37ca6188e4bbe53e0b82e6': ('',
#   u'Can somebody suggest a good place to get a tattoo around here?',
#   5),
#  u'R/5563870eed7fbe0e3ec3cee7918fa': (u'my mantra', u'Just two more weeks', 5),
#  u'R/55638716c648a11b5a2de5fef6c62': (u'On the edge',
#   u"Is it even worth pursuing someone week 9 when we won't be in the same place for summer?",
#   26),
#  u'R/5563871a60a4461a8a766b7bc5889': ('',
#   u'Breaking a mirror is 7 years of bad luck. Breaking a condom is 18 years of bad luck. ',
#   178),
#  u'R/5563873abf78e460811108d3848fe': ('',
#   u'Told a girl to text me when she gets home, she must be homeless. ',
#   88),
#  u'R/5563878adcfc9a4a93a548a63c29f': ('',
#   u"I'm afraid I'll never have friends that I like as much as the friends I have now. Is that a legitimate fear? I just don't want to be an adult with convenience friends, you know? ",
#   11),
#  u'R/556387952808a56a99d07e1a789e1': (u'Dorm Themes', u'Egg Yost', 15),
#  u'R/556387a4cce5dc851f233986ce9c7': (u'Dorm Themes',
#   u'Narnians of the Galaxy',
#   22),
#  u'R/556387b4665ba045c8e7c21c1ecd5': (u'Dorm Themes', u'Stick Schifft', 8),
#  u'R/5563884b28d30ae8a5d1dcc43a78e': ('',
#   u"With graduation coming up, all my friends are finally hooking up with their crushes. Meanwhile, I'm going to graduate a virgin...",
#   31),
#  u'R/556389c0b1436276b1df81585a2ea': ('',
#   u'Struggling hard and ultimately failing to figure out how to word my yaks so that I can still express complex ideas without running out of characters: an autobiogr',
#   29),
#  u'R/55638ac7a6b9b8be2e6e2879cc7ef': ('',
#   u"When you get your burrito back and they didn't fold it properly. And forgot the meat. And the beans. And the guac. And the tortilla. It's made of paper. It's your midterm. You failed.",
#   45),
#  u'R/55638b2957a57c3ee93f63a5ee59e': ('',
#   u'Always laminate your notecards when studying. Not only does it prevent smearing, but the teardrops actually do roll right off',
#   42),
#  u'R/55638bb691c458db6e0512e7e1ef9': ('',
#   u'Okay. Some people like asians with large breasts. We get it.',
#   18),
#  u'R/55638c39c7aa4b04609d0c4b3d229': ('',
#   u'The off-center stars in the Memorial Day reloading banner will be the end of me.',
#   0),
#  u'R/55638cb7d3797056ea58c6387f292': ('',
#   u'I have sexdaily, I mean dyslexia.',
#   89),
#  u'R/55638e285a53a6920bdcd99eeba0c': ('',
#   u"It's a chocolate for breakfast kind of day",
#   6),
#  u'R/55638e5a7c8dd8d614963686a6c02': ('',
#   u"My boyfriend just said he wanted a break for a month and we've been dating for a very long time now. How do I get him back? ",
#   11),
#  u'R/55638e661e92da773d89fb0f5eb03': ('',
#   u'I wanted to go to a party but felt asleep first: an autobiography ',
#   28),
#  u'R/55638e85e2b0e332a79908658f994': (u'graduation',
#   u"All our parents had sex the same year, and that's pretty great!",
#   149),
#  u'R/55638ea01cbfeec35a69810edfd46': ('',
#   u"\U0001f534 Double tap the red button, you won't",
#   23),
#  u'R/556390307edb912b86a89d5b8db88': ('',
#   u'What are those dyson branded urinals? My pee just splashed everywhere! Stupid design!',
#   11),
#  u'R/556390d8764638ea8ac56a99b08e3': ('',
#   u"I've come to terms with the fact that I'm a goddamn idiot and probably should not have children.",
#   20),
#  u'R/556392622ff97fc3a7475893ab801': ('',
#   u"Sweatpants hair tied chillen with no make up on - that's when you're the prettiest ",
#   26),
#  u'R/55639548c4123bc3f93acfdb6b45a': ('',
#   u'Stats 116 vs cs 109: thoughts?',
#   1),
#  u'R/5563955b42e543bcef064a132c7ab': (u'my penis slogan',
#   u'"Large enough to serve, small enough to care."',
#   18),
#  u'R/556395b5f1626273e34d45296b72f': ('',
#   u'When you lower the speed on lecture videos from 2X back to normal and the professor sounds drunk \U0001f37b\U0001f37a\U0001f468\U0001f3fb',
#   52),
#  u'R/55639791477f6301c92a1b1e7a085': ('',
#   u'Why does everyone say "grow some balls"? Balls are weak and sensitive. If you want to be tough grow a vagina - those things can take a pounding. ',
#   40),
#  u'R/556399db39f7ca3f9d599290dc8fd': ('',
#   u"PD people are some of the dumbest I've ever met.",
#   4),
#  u'R/55639a00308ea2dced7794e58a88c': (u'Trust issues',
#   u"Week 9 of spring quarter, still haven't gotten my phebruary prize",
#   26),
#  u'R/55639a960a5475288968b1d222d36': ('',
#   u'True Life: I follow more animals on Instagram than I do humans ',
#   10),
#  u'R/55639aac1f69688c0b26007aa4bcb': (u'23',
#   u"Just counted how many dicks I've sucked while at Stanford ",
#   36),
#  u'R/55639b06e63e48e2d6b6b8df0a4b0': ('',
#   u"Does anyone else hear scary music in their head when they're high ",
#   1),
#  u'R/55639b3fd1504864aa22e3dd4e609': ('',
#   u'When you start making gains  #justManlyThings',
#   5),
#  u'R/55639d486af921096ac4586230dc6': (u'dorm themes', u'ArroYOLO', 4),
#  u'R/55639d6b06e8d416a92dfc2691e24': ('',
#   u'I no longer fear taking a shit in public bathrooms ',
#   25),
#  u'R/55639f231bb53d595550de950f023': ('',
#   u'Visiting from UCLA, how is the economics department here?',
#   3),
#  u'R/55639f3ae4b4adfb838442586fa81': ('',
#   u'The Happy Memorial Day thing on Yik Yak was just so poorly executed..it looks so weird',
#   1),
#  u'R/55639fa7883188825a843886628bc': ('',
#   u'Remember when yo mama jokes were actually funny',
#   15),
#  u'R/5563a190c1fad9e184114ba06eab3': ('',
#   u"In dog beers I've only had one",
#   51),
#  u'R/5563a1ceaa580a4dcc09b418e267d': ('',
#   u'Is Roble Package Center open today? ',
#   2),
#  u'R/5563a21dab181b0b6e6aea196677d': (u'Chem TA',
#   u'Contrary to popular belief, we do not cackle manically and try to fail our students.  ',
#   13),
#  u'R/5563a259b5893f396cfbe7b04e57d': ('',
#   u"I'm perpetually single because I'm too timid to ever make a move on a girl. Anyone have advice on dealing with this?",
#   8),
#  u'R/5563a28be752fd0b65b6ea8f6d074': ('',
#   u'I bet attractive people think the world is a lot more polite than it really is',
#   59),
#  u'R/5563a309ad2507251c3ff7585ab07': ('',
#   u'*gets pulled over* "Sir, do you know why I stopped you today? " " No officer, my snapchat filter said that I was going the speed limit, what\'s the problem?"',
#   25),
#  u'R/5563a32cbd2736c1d0a4d98dd21ed': ('',
#   u'Thanks to the word "indescribable" there\'s nothing that can\'t be described ',
#   25),
#  u'R/5563a365b110eb87e98b5948ebae6': ('',
#   u"I don't get why girls who can have multiple orgasms don't spend literally all their time masturbating",
#   36),
#  u'R/5563a39452e2bd596bb201f703b25': ('',
#   u"If we had no eyes then we would be unaware of the existence of color. What if we are missing an entire aspect of everything simply because we don't have the organ to detect it?",
#   28),
#  u'R/5563a3b53695e064b03023af0befc': ('',
#   u'We will never hear about the truly perfect crime',
#   18),
#  u'R/5563a3d04813fe2e1301488567898': ('',
#   u"Lathrop Tech Lounge is closed today y'all. Don't bother making the trek",
#   10),
#  u'R/5563a3ee6e5714bf855fc61f5b1bc': ('',
#   u'Are any of the gyms open today? ',
#   9),
#  u'R/5563a45a7e60c9e74e4956ea6d75f': (u'dorm names', u'Branner Stark', 15),
#  u'R/5563a4f5185aa106f418aa0ce4471': (u'my life',
#   u'Start the night at 2am, not a soul awake on campus. Where can one find a casual rave on a Saturday night?',
#   6),
#  u'R/5563a5044629cda2d36451f225bb7': ('',
#   u"It annoys me that Engineering students call themselves 'Engineers.' You don't hear medical students calling themselves doctors, or art students calling themselves unemployed",
#   82),
#  u'R/5563a5364167f9acfb1899ff6b2d8': ('',
#   u'any food places open near engineering quad?',
#   3),
#  u'R/5563a61c10fae38909e36c12cd2b2': ('',
#   u'Do girls get turned on by the sight of a penis? Genuinely concerned. ',
#   6),
#  u'R/5563a61e29a02480c27571f837463': ('',
#   u"I don't care about grades to preserve my ego: an autobiography ",
#   34),
#  u'R/5563a61e73ada2fa65f54570eba4a': ('',
#   u"My roommate hasn't left the room at all this weekend and I've been trying to masturbate for like 4 days now",
#   51),
#  u'R/5563a78a3e08f968e3ad40613a2d4': ('',
#   u'Guys that hook up with you once, ignore you for months, and then text you wanting to hook up again \U0001f44e\U0001f623\U0001f63e ',
#   24),
#  u'R/5563a86b621daeb75b243de3a4b67': ('',
#   u'The cheese rolling snapchat story was the only one ever worth watching. ',
#   17),
#  u'R/5563aa89cdbf81f7193f089ede31c': ('',
#   u'Partial credit: an autobiography ',
#   21),
#  u'R/5563ac3f3a2ac6134e24bb69d5334': ('',
#   u'Not finals this week. Calm down.',
#   6),
#  u'R/5563acfe63040ae81cec6145c6f99': ('', u'*insert something sassy here*', 2),
#  u'R/5563ae3c7fb47693facf445a1473a': ('',
#   u"I'm at Starbucks and need to do 30 min max interviews for a class I'm in. I'll buy your drink if you let me interview you. Hit me up please. Thanks! ",
#   -2),
#  u'R/5563ae3d047799fdd12e98e5ba703': (u'Dorm Names', u'Kobe Branner', 7),
#  u'R/5563b30fc504b7497a17577852142': ('',
#   u'Is it sexist to think men react more to the visual while women react more to the emotional?',
#   2),
#  u'R/5563b31e3e8a21352c4f90191e079': ('',
#   u"Greek life at stanford DNE Greek life at other schools.  The nongreek section of campus has it so good here and so many don't even know it. Visit an SEC school if you don't believe me. ",
#   13),
#  u'R/5563b67d8ffaac359e4d4a0effe29': ('',
#   u"Dear person who sped through a stop sign in a fucking SUV: you could have killed me. You're not entitled to feel rebellious at the expense of others.",
#   16),
#  u'R/5563b6d5e332de7a39cd8a782e68c': (u'Long Weekend',
#   u'Bottomless mimosas for brunch and afternoon naps.',
#   7),
#  u'R/5563b7d3d46b5588d8a2094d02bd6': ('',
#   u"When you have so much work to do that you've resorted to working on a paper while using the bathroom.",
#   4),
#  u'R/5563b9d1331fa9a824d562f5495cf': (u'fwp',
#   u"I hate when I'm tired but not tired enough to take a nap",
#   6),
#  u'R/5563ba21db89f611f9076dffe4573': ('', u'ACSR <<< AOERC', 4),
#  u'R/5563bc51acb982d3f0844a603dd44': (u'Meant To Be',
#   u"I've seen this same guy at the Tresider area like five times in the past three days or so. Never seen him before in my life. ",
#   -1),
#  u'R/5563bc8d7eee7bc429d18ca612cc1': ('',
#   u"When you find something out that & that's all you can think about but you have a ton of work to do. ",
#   2),
#  u'R/5563bd320904487ecbe0601d83d3e': ('',
#   u'Many one want to have a 3 way with my boyfriend and I (female here)? Mfm or mff both work',
#   1),
#  u'R/5563bd3d4dbce34f0b81cedf71522': ('',
#   u"I really want a boyfriend but I'm way too awkward to keep one",
#   0),
#  u'Y/605bdd205732cd448ecc139e18ef2f70': ('',
#   u'Hold up you beautiful person, if you wanna do anything more than read yaks you gotta download our new update.\r\nNow you can search and save custom peek locations anywhere in the world!\r\nSo do yourself a favor and shower yourself in the glory of this new update. Ride on.',
#   10000)}

# %%
'handle' in most_recent_yaks[1]
# Out:
# True

# %%
s = {2, 3}
